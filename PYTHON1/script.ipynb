# %%
import pandas as pd
import numpy as np
from tkinter import *
from tkinter import filedialog

# %% [markdown]
# # Read data:

# %%
# read data
# ask for file .csv

#decomment#Tk().withdraw()
#decomment#file_path = filedialog.askopenfilename(defaultextension='.csv')

# import data from csv file
#decomment#event = pd.read_csv(file_path, skipinitialspace=True, delimiter=";")
event = pd.read_csv("./data/event.csv", skipinitialspace=True, delimiter=";")

# import teams and host groups
teams = pd.read_csv("./data/teams.csv", delimiter=";", header=None)
teams.drop(teams.columns[0], axis=1, inplace=True)

# %%
# test data
event.head(5)
# Out:
#          HostName                                        Description  \
# 0    rc51e00vm013                  SNMP Not Reachable on {HOST.NAME}
# 1       m11sdp20b  [p]Ebill: HTTP Connection time from Web Front ...
# 2        dc1occ05  [p]Shop-POS/en: HTTP service is down on Web Ap...
# 3  Pentaho_Server                                       Output CDR 1
# 4   rc51e00vm015b  [p]Ebill: HTTP Connection time from Web Front ...
#
#    Severity   Status          Occurrence_Time
# 0         -  PROBLEM  July 1, 2020, 1:50 a.m.
# 1         -  PROBLEM  July 1, 2020, 1:50 a.m.
# 2  DISASTER  PROBLEM  July 1, 2020, 1:49 a.m.
# 3         -  PROBLEM  July 1, 2020, 1:49 a.m.
# 4      HIGH  PROBLEM  July 1, 2020, 1:48 a.m.

# %%
# test teams and hosts data
# teams
# test - search for a hostname
#print(teams[[c for c in teams.columns if (teams[c].str.contains("m4csnmt2") == True).any()][0]][0])

# init emails
emails = {
    'Charging System': 'charging.system.ericsson16@gmail.com',
    'Channels Team': 'tchannels.team.ericsson16@gmail.com',
    'Order Management Team': 'order.management.team.ericsson16@gmail.com',
    'Billing Team': 'billing.team.ericsson16@gmail.com',
    'Infra Team': 'infra.team.ericsson16@gmail.com',
    'Security Team': 'helpdeskenp@gmail.com'
}

# %% [markdown]
# # Prepare data:

# %%
# drop the NaN values
event.dropna(how="all", inplace=True)

# %%
# define the Severity sorter
sorter = ["INFORMATION", "WARNING", "AVERAGE", "HIGH", "DISASTER"]

# create the dictionary that defines the order for sorting
sorterIndex = dict(zip(sorter,range(len(sorter))))

# generate a rank column that will be used to sort
# the dataframe numerically
event['Severity_Rank'] = event['Severity'].map(sorterIndex)

event.sort_values('Severity_Rank', ascending = True, inplace=True)
event.drop('Severity_Rank', 1, inplace = True)
event
# Out:
#                HostName                                        Description  \
# 14        rc51e00vm012a  [p]MyAccount: HTTP service is down on Web App ...
# 4         rc51e00vm015b  [p]Ebill: HTTP Connection time from Web Front ...
# 5        Pentaho_Server  [p]Ebill: HTTP service is down on Web App 10.9...
# 8         rc51e00vm007h  [p]POS: HTTP Connection time from Web Front 1 ...
# 11        rc51e00vm016b  R01 Process Count on enh_core_db_1 and enh_cor...
# 15               m8air6            Generic error during ftp on {HOST.HOST}
# 17        rc51e00vm003m  [p]B2C Sales Chanel: Webshop: HTTP Connection ...
# 2              dc1occ05  [p]Shop-POS/en: HTTP service is down on Web Ap...
# 6             dzalb01a2  [p]Customer Care:Self Check HTTP: HTTP Connect...
# 10              s1ipgw2          Message Queue Performance Monitor for MQ2
# 12             m9sdp16a                CPU utilization is greater than 70%
# 18             m5sdp25a  [p]B2C Sales Chanel: Webshop: HTTP Connection ...
# 0          rc51e00vm013                  SNMP Not Reachable on {HOST.NAME}
# 1             m11sdp20b  [p]Ebill: HTTP Connection time from Web Front ...
# 3        Pentaho_Server                                       Output CDR 1
# 7              m9sdp16a  [p]POS: HTTP Connection time from Web Front to...
# 9         rc51e00vm007g                 {HOST.NAME} is unavailable by ICMP
# 13      ALG-S1-L-STR001          Error renaming remote file on {HOST.HOST}
# 16  djezzy-dc2-emm-cps1    Memory usage is greater than 70% on {HOST.NAME}
# 19         rc51e00h002a  Medallia dump : crm#contractscontract is not s...
# 20                 TEST                                            network
# 21         KPI probleme                                EDA stopped working
# 22                  sdp                                           probleme
#
#     Severity      Status          Occurrence_Time
# 14   AVERAGE     PROBLEM  July 1, 2020, 1:42 a.m.
# 4       HIGH     PROBLEM  July 1, 2020, 1:48 a.m.
# 5       HIGH     PROBLEM  July 1, 2020, 1:48 a.m.
# 8       HIGH     PROBLEM  July 1, 2020, 1:46 a.m.
# 11      HIGH     PROBLEM  July 1, 2020, 1:44 a.m.
# 15      HIGH     PROBLEM  July 1, 2020, 1:41 a.m.
# 17      HIGH     PROBLEM  July 1, 2020, 1:40 a.m.
# 2   DISASTER     PROBLEM  July 1, 2020, 1:49 a.m.
# 6   DISASTER     PROBLEM  July 1, 2020, 1:47 a.m.
# 10  DISASTER     PROBLEM  July 1, 2020, 1:44 a.m.
# 12  DISASTER     PROBLEM  July 1, 2020, 1:43 a.m.
# 18  DISASTER     PROBLEM  July 1, 2020, 1:40 a.m.
# 0          -     PROBLEM  July 1, 2020, 1:50 a.m.
# 1          -     PROBLEM  July 1, 2020, 1:50 a.m.
# 3          -     PROBLEM  July 1, 2020, 1:49 a.m.
# 7          -     PROBLEM  July 1, 2020, 1:47 a.m.
# 9          -     PROBLEM  July 1, 2020, 1:45 a.m.
# 13         -     PROBLEM  July 1, 2020, 1:43 a.m.
# 16         -     PROBLEM  July 1, 2020, 1:41 a.m.
# 19         -     PROBLEM  July 1, 2020, 1:40 a.m.
# 20         1           0      06/30/2020 19:39:44
# 21       NaN  INPROGRESS      06/30/2020 19:28:43
# 22      High         New      06/30/2020 18:51:12

# %%
# drop duplicate Description and keep the last Serverity
event.drop_duplicates(subset='Description', keep='last', inplace=True)
event
# Out:
#                HostName                                        Description  \
# 14        rc51e00vm012a  [p]MyAccount: HTTP service is down on Web App ...
# 4         rc51e00vm015b  [p]Ebill: HTTP Connection time from Web Front ...
# 5        Pentaho_Server  [p]Ebill: HTTP service is down on Web App 10.9...
# 8         rc51e00vm007h  [p]POS: HTTP Connection time from Web Front 1 ...
# 11        rc51e00vm016b  R01 Process Count on enh_core_db_1 and enh_cor...
# 15               m8air6            Generic error during ftp on {HOST.HOST}
# 17        rc51e00vm003m  [p]B2C Sales Chanel: Webshop: HTTP Connection ...
# 2              dc1occ05  [p]Shop-POS/en: HTTP service is down on Web Ap...
# 6             dzalb01a2  [p]Customer Care:Self Check HTTP: HTTP Connect...
# 10              s1ipgw2          Message Queue Performance Monitor for MQ2
# 12             m9sdp16a                CPU utilization is greater than 70%
# 18             m5sdp25a  [p]B2C Sales Chanel: Webshop: HTTP Connection ...
# 0          rc51e00vm013                  SNMP Not Reachable on {HOST.NAME}
# 1             m11sdp20b  [p]Ebill: HTTP Connection time from Web Front ...
# 3        Pentaho_Server                                       Output CDR 1
# 7              m9sdp16a  [p]POS: HTTP Connection time from Web Front to...
# 9         rc51e00vm007g                 {HOST.NAME} is unavailable by ICMP
# 13      ALG-S1-L-STR001          Error renaming remote file on {HOST.HOST}
# 16  djezzy-dc2-emm-cps1    Memory usage is greater than 70% on {HOST.NAME}
# 19         rc51e00h002a  Medallia dump : crm#contractscontract is not s...
# 20                 TEST                                            network
# 21         KPI probleme                                EDA stopped working
# 22                  sdp                                           probleme
#
#     Severity      Status          Occurrence_Time
# 14   AVERAGE     PROBLEM  July 1, 2020, 1:42 a.m.
# 4       HIGH     PROBLEM  July 1, 2020, 1:48 a.m.
# 5       HIGH     PROBLEM  July 1, 2020, 1:48 a.m.
# 8       HIGH     PROBLEM  July 1, 2020, 1:46 a.m.
# 11      HIGH     PROBLEM  July 1, 2020, 1:44 a.m.
# 15      HIGH     PROBLEM  July 1, 2020, 1:41 a.m.
# 17      HIGH     PROBLEM  July 1, 2020, 1:40 a.m.
# 2   DISASTER     PROBLEM  July 1, 2020, 1:49 a.m.
# 6   DISASTER     PROBLEM  July 1, 2020, 1:47 a.m.
# 10  DISASTER     PROBLEM  July 1, 2020, 1:44 a.m.
# 12  DISASTER     PROBLEM  July 1, 2020, 1:43 a.m.
# 18  DISASTER     PROBLEM  July 1, 2020, 1:40 a.m.
# 0          -     PROBLEM  July 1, 2020, 1:50 a.m.
# 1          -     PROBLEM  July 1, 2020, 1:50 a.m.
# 3          -     PROBLEM  July 1, 2020, 1:49 a.m.
# 7          -     PROBLEM  July 1, 2020, 1:47 a.m.
# 9          -     PROBLEM  July 1, 2020, 1:45 a.m.
# 13         -     PROBLEM  July 1, 2020, 1:43 a.m.
# 16         -     PROBLEM  July 1, 2020, 1:41 a.m.
# 19         -     PROBLEM  July 1, 2020, 1:40 a.m.
# 20         1           0      06/30/2020 19:39:44
# 21       NaN  INPROGRESS      06/30/2020 19:28:43
# 22      High         New      06/30/2020 18:51:12

# %%
# drop duplicate HostName and keep the last Serverity
event.drop_duplicates(subset='HostName', keep='last', inplace=True)
event
# Out:
#                HostName                                        Description  \
# 14        rc51e00vm012a  [p]MyAccount: HTTP service is down on Web App ...
# 4         rc51e00vm015b  [p]Ebill: HTTP Connection time from Web Front ...
# 8         rc51e00vm007h  [p]POS: HTTP Connection time from Web Front 1 ...
# 11        rc51e00vm016b  R01 Process Count on enh_core_db_1 and enh_cor...
# 15               m8air6            Generic error during ftp on {HOST.HOST}
# 17        rc51e00vm003m  [p]B2C Sales Chanel: Webshop: HTTP Connection ...
# 2              dc1occ05  [p]Shop-POS/en: HTTP service is down on Web Ap...
# 6             dzalb01a2  [p]Customer Care:Self Check HTTP: HTTP Connect...
# 10              s1ipgw2          Message Queue Performance Monitor for MQ2
# 18             m5sdp25a  [p]B2C Sales Chanel: Webshop: HTTP Connection ...
# 0          rc51e00vm013                  SNMP Not Reachable on {HOST.NAME}
# 1             m11sdp20b  [p]Ebill: HTTP Connection time from Web Front ...
# 3        Pentaho_Server                                       Output CDR 1
# 7              m9sdp16a  [p]POS: HTTP Connection time from Web Front to...
# 9         rc51e00vm007g                 {HOST.NAME} is unavailable by ICMP
# 13      ALG-S1-L-STR001          Error renaming remote file on {HOST.HOST}
# 16  djezzy-dc2-emm-cps1    Memory usage is greater than 70% on {HOST.NAME}
# 19         rc51e00h002a  Medallia dump : crm#contractscontract is not s...
# 20                 TEST                                            network
# 21         KPI probleme                                EDA stopped working
# 22                  sdp                                           probleme
#
#     Severity      Status          Occurrence_Time
# 14   AVERAGE     PROBLEM  July 1, 2020, 1:42 a.m.
# 4       HIGH     PROBLEM  July 1, 2020, 1:48 a.m.
# 8       HIGH     PROBLEM  July 1, 2020, 1:46 a.m.
# 11      HIGH     PROBLEM  July 1, 2020, 1:44 a.m.
# 15      HIGH     PROBLEM  July 1, 2020, 1:41 a.m.
# 17      HIGH     PROBLEM  July 1, 2020, 1:40 a.m.
# 2   DISASTER     PROBLEM  July 1, 2020, 1:49 a.m.
# 6   DISASTER     PROBLEM  July 1, 2020, 1:47 a.m.
# 10  DISASTER     PROBLEM  July 1, 2020, 1:44 a.m.
# 18  DISASTER     PROBLEM  July 1, 2020, 1:40 a.m.
# 0          -     PROBLEM  July 1, 2020, 1:50 a.m.
# 1          -     PROBLEM  July 1, 2020, 1:50 a.m.
# 3          -     PROBLEM  July 1, 2020, 1:49 a.m.
# 7          -     PROBLEM  July 1, 2020, 1:47 a.m.
# 9          -     PROBLEM  July 1, 2020, 1:45 a.m.
# 13         -     PROBLEM  July 1, 2020, 1:43 a.m.
# 16         -     PROBLEM  July 1, 2020, 1:41 a.m.
# 19         -     PROBLEM  July 1, 2020, 1:40 a.m.
# 20         1           0      06/30/2020 19:39:44
# 21       NaN  INPROGRESS      06/30/2020 19:28:43
# 22      High         New      06/30/2020 18:51:12

# %%
# add email here
#print(list(event["HostName"]))
Email = []
for host_name in list(event["HostName"]):
    #print(host_name)
    try:
        Email.append(emails[teams[[c for c in teams.columns if (teams[c].str.contains(host_name) == True).any()][0]][0]])
    except IndexError:
        Email.append("ahmed_chawki.harchouche@g.enp.edu.dz")
    #print(teams[[c for c in teams.columns if (teams[c].str.contains(host_name) == True).any()][0]][0])
#event2 = event.assign(Email = [teams[[c for c in teams.columns if (teams[c].str.contains(host_name) == True).any()][0]][0] for host_name in list(event["HostName"])])
event2 = event.assign(Email = Email)
event2
# Out:
#                HostName                                        Description  \
# 14        rc51e00vm012a  [p]MyAccount: HTTP service is down on Web App ...
# 4         rc51e00vm015b  [p]Ebill: HTTP Connection time from Web Front ...
# 8         rc51e00vm007h  [p]POS: HTTP Connection time from Web Front 1 ...
# 11        rc51e00vm016b  R01 Process Count on enh_core_db_1 and enh_cor...
# 15               m8air6            Generic error during ftp on {HOST.HOST}
# 17        rc51e00vm003m  [p]B2C Sales Chanel: Webshop: HTTP Connection ...
# 2              dc1occ05  [p]Shop-POS/en: HTTP service is down on Web Ap...
# 6             dzalb01a2  [p]Customer Care:Self Check HTTP: HTTP Connect...
# 10              s1ipgw2          Message Queue Performance Monitor for MQ2
# 18             m5sdp25a  [p]B2C Sales Chanel: Webshop: HTTP Connection ...
# 0          rc51e00vm013                  SNMP Not Reachable on {HOST.NAME}
# 1             m11sdp20b  [p]Ebill: HTTP Connection time from Web Front ...
# 3        Pentaho_Server                                       Output CDR 1
# 7              m9sdp16a  [p]POS: HTTP Connection time from Web Front to...
# 9         rc51e00vm007g                 {HOST.NAME} is unavailable by ICMP
# 13      ALG-S1-L-STR001          Error renaming remote file on {HOST.HOST}
# 16  djezzy-dc2-emm-cps1    Memory usage is greater than 70% on {HOST.NAME}
# 19         rc51e00h002a  Medallia dump : crm#contractscontract is not s...
# 20                 TEST                                            network
# 21         KPI probleme                                EDA stopped working
# 22                  sdp                                           probleme
#
#     Severity      Status          Occurrence_Time  \
# 14   AVERAGE     PROBLEM  July 1, 2020, 1:42 a.m.
# 4       HIGH     PROBLEM  July 1, 2020, 1:48 a.m.
# 8       HIGH     PROBLEM  July 1, 2020, 1:46 a.m.
# 11      HIGH     PROBLEM  July 1, 2020, 1:44 a.m.
# 15      HIGH     PROBLEM  July 1, 2020, 1:41 a.m.
# 17      HIGH     PROBLEM  July 1, 2020, 1:40 a.m.
# 2   DISASTER     PROBLEM  July 1, 2020, 1:49 a.m.
# 6   DISASTER     PROBLEM  July 1, 2020, 1:47 a.m.
# 10  DISASTER     PROBLEM  July 1, 2020, 1:44 a.m.
# 18  DISASTER     PROBLEM  July 1, 2020, 1:40 a.m.
# 0          -     PROBLEM  July 1, 2020, 1:50 a.m.
# 1          -     PROBLEM  July 1, 2020, 1:50 a.m.
# 3          -     PROBLEM  July 1, 2020, 1:49 a.m.
# 7          -     PROBLEM  July 1, 2020, 1:47 a.m.
# 9          -     PROBLEM  July 1, 2020, 1:45 a.m.
# 13         -     PROBLEM  July 1, 2020, 1:43 a.m.
# 16         -     PROBLEM  July 1, 2020, 1:41 a.m.
# 19         -     PROBLEM  July 1, 2020, 1:40 a.m.
# 20         1           0      06/30/2020 19:39:44
# 21       NaN  INPROGRESS      06/30/2020 19:28:43
# 22      High         New      06/30/2020 18:51:12
#
#                                          Email
# 14         tchannels.team.ericsson16@gmail.com
# 4          tchannels.team.ericsson16@gmail.com
# 8          tchannels.team.ericsson16@gmail.com
# 11  order.management.team.ericsson16@gmail.com
# 15        charging.system.ericsson16@gmail.com
# 17  order.management.team.ericsson16@gmail.com
# 2         charging.system.ericsson16@gmail.com
# 6   order.management.team.ericsson16@gmail.com
# 10  order.management.team.ericsson16@gmail.com
# 18        charging.system.ericsson16@gmail.com
# 0         ahmed_chawki.harchouche@g.enp.edu.dz
# 1         charging.system.ericsson16@gmail.com
# 3         ahmed_chawki.harchouche@g.enp.edu.dz
# 7         charging.system.ericsson16@gmail.com
# 9          tchannels.team.ericsson16@gmail.com
# 13             infra.team.ericsson16@gmail.com
# 16        ahmed_chawki.harchouche@g.enp.edu.dz
# 19  order.management.team.ericsson16@gmail.com
# 20        ahmed_chawki.harchouche@g.enp.edu.dz
# 21        ahmed_chawki.harchouche@g.enp.edu.dz
# 22        charging.system.ericsson16@gmail.com

# %%
# export data
Tk().withdraw()
export_file_path = filedialog.asksaveasfilename(defaultextension='.csv')
event2.to_csv(export_file_path, index = False, header=True, sep=";")
